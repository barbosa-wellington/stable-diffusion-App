# %%
import pandas as pd
import numpy as np

from glob import glob
import cv2
import matplotlib.pylab as plt
from PIL import Image

# %% [markdown]
# ## This notebook is a research tool for working with image processing
#
# # referene: https://www.youtube.com/watch?v=kSqxn6zGE0c

# %%
ima = Image.open("D:/tmp/stable-diffusion-webui-master/outputs/txt2img-images/2026-05-31/00000-1376750283.png")
ima
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
test = glob('D:/tmp/stable-diffusion-webui-master/outputs/txt2img-images/2026-05-31/*.png')

# %%
plt.imread(test[0])
# Out:
# array([[[0.40784314, 0.5411765 , 0.11372549],
#         [0.3254902 , 0.5176471 , 0.00392157],
#         [0.38039216, 0.5882353 , 0.0627451 ],
#         ...,
#         [0.07450981, 0.12156863, 0.01568628],
#         [0.14901961, 0.18039216, 0.03921569],
#         [0.12941177, 0.10980392, 0.        ]],
#
#        [[0.4117647 , 0.6117647 , 0.06666667],
#         [0.39607844, 0.64705884, 0.03921569],
#         [0.3647059 , 0.61960787, 0.03137255],
#         ...,
#         [0.07058824, 0.10196079, 0.02352941],
#         [0.11764706, 0.20784314, 0.03921569],
#         [0.07843138, 0.05490196, 0.        ]],
#
#        [[0.43137255, 0.69803923, 0.08627451],
#         [0.4       , 0.6784314 , 0.07843138],
#         [0.3764706 , 0.654902  , 0.04313726],
#         ...,
#         [0.02745098, 0.0627451 , 0.        ],
#         [0.05882353, 0.11372549, 0.02352941],
#         [0.05882353, 0.06666667, 0.        ]],
#
#        ...,
#
#        [[0.05882353, 0.05490196, 0.00784314],
# ...

# %%
img_cv2 = cv2.imread(test[0])

# %%
# identify array type

# %%
img_cv2.shape
# Out:
# (512, 512, 3)
